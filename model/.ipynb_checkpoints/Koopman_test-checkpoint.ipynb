# %%
# %matplotlib notebook
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
from data_loader import produce_dataset, get_dataloaders, dataset_plot
from train import *
from test_function import *
from model_nn import Koopman
import numpy as np
import torch
initial_out = sys.stdout

# %% [markdown]
# ## Dataset generation

# %%
# create dataset (optional)
x_range = np.array([2.,2.,3])
u_range = np.array([1.5,0.5])
SimLength=20
Ntraj = 500000
Ts=0.1
path = produce_dataset(x_range,u_range,SimLength,Ntraj,Ts)
sys.stdout = initial_out
print(path)
# Out:
# Start simulating...
# ...
# 100%|██████████| 100000/100000 [00:17<00:00, 5574.51it/s]
# Dataset produced.
# Dataset saved.
# ./dataset/state-[2. 2. 3.]_input-[1.5 0.5]_2.0x500000_Ts_0.1

# %%
#path = './dataset/noise-0.1_dest-[5. 3.]_K-20_0.2x100000_Ts_0.01'
dataset_plot(path,num=1000)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Preparation

# %%
# get dataloaders
batch_size = 100
path = './dataset/state-[2. 2. 3.]_input-[1.5 0.5]_2.0x100000_Ts_0.1'
train_loader, val_loader, test_loader = get_dataloaders(path,batch_size)

# %% [markdown]
# ### Initial baseline - from paper

# %%
# get parameters
K = 7
arg = {
    'encoder':[3,32,64,K],
    'decoder':[K+3,128,64,32,3],
    'hyper':[1.0,1.0,0.3,1e-9,1e-9,1e-9,6]
}

# start training
epochs=400
file_name = train_the_model(train_loader, val_loader, arg, batch_size, epochs)
plot_learning_curve(file_name)

# get test result
test_the_model(test_loader, file_name)
print(file_name)
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
# Trainer created.
# ...
# Epoch 400: 100%|██████████| 600/600 [00:26<00:00, 22.94it/s, loss=0.101]
# <img src="data:image/png;base64,..." width="640">
# 100%|██████████| 200/200 [00:06<00:00, 31.98it/s]
# General loss: 0.026698632426559926.
#
# MSE loss: 0.0007233502934104762.
# encoder_[3, 32, 64, 7]_decoder_[10, 128, 64, 32, 3]_hyper_[1.0, 1.0, 0.3, 1e-09, 1e-09, 1e-09, 6]_batch_100

# %%
file_names = [
    'encoder_[3, 32, 64, 7]_decoder_[10, 128, 64, 32, 3]_hyper_[1.0, 1.0, 0.3, 1e-09, 1e-09, 1e-09, 6]_batch_100',
]
result_sample(path,file_names,index=800)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ### Varying length

# %%
for i in range(3,8):
    # get parameters
    K = 7
    arg = {
        'encoder':[3,32,64,K],
        'decoder':[K+3,128,64,32,3],
        'hyper':[1.0,1.0,0.3,0.000000001,0.000000001,0.000000001,i]
    }

    # start training
    epochs=50
    file_name = train_the_model(train_loader, val_loader, arg, batch_size, epochs)
    plot_learning_curve(file_name)

    # get test result
    test_the_model(test_loader, file_name)
    print(file_name)
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
# Trainer created.
# ...
# Epoch 25:  63%|██████▎   | 380/600 [00:10<00:05, 41.39it/s, loss=0.078]

# %% [markdown]
# ### Varing regularisation

# %% [markdown]
# ### Varying different loss

# %% [markdown]
# ### Change model structure

# %% [markdown]
# #### Varying lifted state

# %% [markdown]
# #### Varying hidden nodes

# %% [markdown]
# #### Varying hidden layers

# %% [markdown]
# ## Result Analysis

# %%
# %matplotlib notebook
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
from data_loader import produce_dataset, get_dataloaders, dataset_plot
from train import *
from test_function import *
from model_nn import Koopman
import numpy as np
import torch
initial_out = sys.stdout

# %%
path = './dataset/state-[2. 2. 3.]_input-[1.5 0.5]_0.2x500000_Ts_0.01'
file_names = [
    'encoder_[3, 32, 64, 6]_decoder_[9, 128, 64, 32, 3]_hyper_[1.0, 1.0, 0.3, 1e-09, 1e-09, 1e-09, 2]_batch_1000',
    'encoder_[3, 32, 64, 6]_decoder_[9, 128, 64, 32, 3]_hyper_[1.0, 1.0, 0.3, 1e-09, 1e-09, 1e-09, 4]_batch_1000',
    'encoder_[3, 32, 64, 6]_decoder_[9, 128, 64, 32, 3]_hyper_[1.0, 1.0, 0.3, 1e-09, 1e-09, 1e-09, 6]_batch_1000',
    'encoder_[3, 32, 64, 6]_decoder_[9, 128, 64, 32, 3]_hyper_[1.0, 1.0, 0.3, 1e-09, 1e-09, 1e-09, 8]_batch_1000',
    'encoder_[3, 32, 64, 6]_decoder_[9, 128, 64, 32, 3]_hyper_[1.0, 1.0, 0.3, 1e-09, 1e-09, 1e-09, 10]_batch_1000',
    'encoder_[3, 32, 64, 8]_decoder_[11, 128, 64, 32, 3]_hyper_[1.0, 1.0, 0.3, 1e-09, 1e-09, 1e-09, 6]_batch_1000',
    'encoder_[3, 32, 64, 10]_decoder_[13, 128, 64, 32, 3]_hyper_[1.0, 1.0, 0.3, 1e-09, 1e-09, 1e-09, 6]_batch_1000'
]
result_sample(path,file_names,index=241)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
import torch
print(torch.__version__)
# Out:
# 1.4.0

# %%
xx = np.load(path+"/X_test.npy")
xx = xx[0,:,:]
xx = torch.tensor(xx).float()
xx = xx.unsqueeze(0)
x = xx[:,2,:]
print(x.shape)
# Out:
# torch.Size([1, 6])

# %%
index = 3
xx = np.load(path+"/X_test.npy")
uu = np.load(path+"/U_test.npy")
xx = xx[index]
uu = uu[index]
yy = xx[:-1]
print(xx.shape)
print(uu.shape)
print(yy.shape)
# Out:
# (101, 6)
# (100, 3)
# (100, 6)

# %%
for i, data in enumerate(test_loader):
    X, U=data
    X = X.to(device)
    U = U.to(device)
    loss = loss_function(model,X,U) 
print(U.shape)
# Out:
# torch.Size([1, 3, 100])

# %%
model = Koopman(hidden_layer=2)
submodules = []
for idx, m in enumerate(model.named_children()):
    submodules.append(m)
en = submodules[0][1]
de = submodules[1][1]
K = submodules[2][1]
print(en)
# Out:
# encoder(
#   (input_layer): Sequential(
#     (0): Linear(in_features=6, out_features=30, bias=True)
#     (1): ReLU()
#   )
#   (hidden_layers): Sequential(
#     (0): Linear(in_features=30, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=30, bias=True)
#     (3): ReLU()
#   )
#   (output_layer): Sequential(
#     (0): Linear(in_features=30, out_features=30, bias=True)
#     (1): ReLU()
#   )
# )

# %%
print(torch.cuda.device_count())
# Out:
# 1

# %%
for name, param in model.named_parameters():
    print(param)
# Out:
# Parameter containing:
# tensor([[ 0.1634, -0.1321, -0.3789, -0.2369,  0.2696,  0.2819],
#         [-0.1659,  0.0839, -0.0814, -0.1603,  0.0260,  0.0618],
#         [-0.2136,  0.2609,  0.2690,  0.0800,  0.1249,  0.2763],
#         [ 0.1359, -0.0447,  0.0203, -0.1896,  0.2178,  0.1025],
#         [ 0.2433, -0.3513, -0.2933, -0.1141, -0.3179,  0.3055],
#         [-0.2136, -0.0317,  0.1539, -0.1149,  0.2557, -0.3906],
#         [ 0.3235,  0.2800,  0.3244, -0.4045,  0.1815, -0.1580],
#         [ 0.3538, -0.2212, -0.3395, -0.2431,  0.1884,  0.0690],
#         [ 0.1700, -0.2066,  0.2711, -0.2969, -0.3780, -0.0643],
#         [ 0.0086, -0.1699,  0.3263, -0.1935,  0.3561, -0.1834],
#         [-0.2999, -0.2621,  0.2051, -0.0623,  0.2622,  0.3451],
#         [ 0.0678, -0.2828, -0.0611, -0.0988,  0.2126, -0.0568],
#         [ 0.2961, -0.1256,  0.0666, -0.1656, -0.2574, -0.3966],
#         [ 0.1050,  0.0308,  0.3170, -0.3695, -0.3836,  0.2249],
# ...

# %%
xx = np.load("./dataset/state-[4. 4. 3.]_input-[200. 200.]_0.05x100000_Ts_0.01/X_test.npy")
xx = xx[0]
print(xx.shape[0])
# Out:
# 6
